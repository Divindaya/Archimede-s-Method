# %%
import math

def archimethod(n0, side1, n, m):
    radius = 1
    a = math.sqrt(radius - (side1/2)**2)
    b = radius - a
    s2 = math.sqrt(b**2 + (side1/2)**2)
    p = n0 * side1
    d = 2
    print('n =', n0)
    print('lower limit ratio is ', p/d)

    n1 = n0 * 2
    p1 = n1 * s2

    k = radius/a
    p2 = p * k

    print('upper limit ratio is ', p2/d)

    mean = (p/d + p2/d)/2
    print('mean value is', mean)
    print('difference is', p2/d - p/d)
    print('------------------------------------------')

    if n1 <= 2**m*n:
        archimethod(n1, s2, n, m)


def main():
    n0 = int(input('Enter n:'))
    m = int(input('Enter m:'))
    side1 = 1 ## length of one side of hexagon in unit circle
    archimethod(n0, side1, n0, m)

main()
# Out:
# n = 6
# lower limit ratio is  3.0
# upper limit ratio is  3.4641016151377553
# mean value is 3.2320508075688776
# difference is 0.4641016151377553
# ------------------------------------------
# n = 12
# lower limit ratio is  3.105828541230249
# upper limit ratio is  3.215390309173472
# mean value is 3.1606094252018604
# difference is 0.10956176794322303
# ------------------------------------------
# n = 24
# lower limit ratio is  3.1326286132812378
# upper limit ratio is  3.1596599420975005
# mean value is 3.146144277689369
# difference is 0.02703132881626269
# ------------------------------------------
# n = 48
# lower limit ratio is  3.1393502030468667
# upper limit ratio is  3.1460862151314344
# mean value is 3.142718209089151
# difference is 0.006736012084567644
# ------------------------------------------
# n = 96
# lower limit ratio is  3.14103195089051
# upper limit ratio is  3.1427145996453687
# mean value is 3.1418732752679395
# difference is 0.0016826487548589064
# ------------------------------------------
# n = 192
# lower limit ratio is  3.1414524722854624
# upper limit ratio is  3.141873049979824
# mean value is 3.1416627611326433
# difference is 0.00042057769436176784
# ------------------------------------------
# n = 384
# lower limit ratio is  3.141557607911858
# upper limit ratio is  3.1416627470568486
# mean value is 3.1416101774843534
# difference is 0.00010513914499066246
# ------------------------------------------
# n = 768
# lower limit ratio is  3.1415838921483186
# upper limit ratio is  3.1416101766046896
# mean value is 3.1415970343765043
# difference is 2.628445637098409e-05
# ------------------------------------------
# n = 1536
# lower limit ratio is  3.1415904632280505
# upper limit ratio is  3.1415970343215265
# mean value is 3.1415937487747883
# difference is 6.571093476015477e-06
# ------------------------------------------
# n = 3072
# lower limit ratio is  3.1415921059992717
# upper limit ratio is  3.141593748771352
# mean value is 3.141592927385312
# difference is 1.64277208014596e-06
# ------------------------------------------
# n = 6144
# lower limit ratio is  3.1415925166921577
# upper limit ratio is  3.141592927385097
# mean value is 3.1415927220386273
# difference is 4.106929392122538e-07
# ------------------------------------------
# n = 12288
# lower limit ratio is  3.141592619365384
# upper limit ratio is  3.141592722038614
# mean value is 3.141592670701999
# difference is 1.0267322991808214e-07
# ------------------------------------------
# n = 24576
# lower limit ratio is  3.141592645033691
# upper limit ratio is  3.141592670701998
# mean value is 3.141592657867845
# difference is 2.5668307035431326e-08
# ------------------------------------------
# n = 49152
# lower limit ratio is  3.141592651450768
# upper limit ratio is  3.141592657867845
# mean value is 3.1415926546593065
# difference is 6.417076647835529e-09
# ------------------------------------------
# n = 98304
# lower limit ratio is  3.1415926530550373
# upper limit ratio is  3.141592654659307
# mean value is 3.141592653857172
# difference is 1.604269606048092e-09
# ------------------------------------------
# n = 196608
# lower limit ratio is  3.1415926534561045
# upper limit ratio is  3.1415926538571726
# mean value is 3.1415926536566383
# difference is 4.010680676458378e-10
# ------------------------------------------
# n = 393216
# lower limit ratio is  3.141592653556372
# upper limit ratio is  3.141592653656639
# mean value is 3.1415926536065055
# difference is 1.0026734997836684e-10
# ------------------------------------------
# n = 786432
# lower limit ratio is  3.141592653581438
# upper limit ratio is  3.1415926536065055
# mean value is 3.141592653593972
# difference is 2.5067503628406484e-11
# ------------------------------------------
# n = 1572864
# lower limit ratio is  3.1415926535877046
# upper limit ratio is  3.1415926535939716
# mean value is 3.141592653590838
# difference is 6.266986929404084e-12
# ------------------------------------------
# n = 3145728
# lower limit ratio is  3.1415926535892713
# upper limit ratio is  3.141592653590838
# mean value is 3.1415926535900547
# difference is 1.566746732351021e-12
# ------------------------------------------
# n = 6291456
# lower limit ratio is  3.141592653589663
# upper limit ratio is  3.141592653590055
# mean value is 3.141592653589859
# difference is 3.921307722976053e-13
# ------------------------------------------
